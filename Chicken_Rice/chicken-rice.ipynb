# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ChickenRiceDatasetNew.csv')
df.head()
# Out:
#    S/N                                              Stall  \
# 0    1              Ah Boy Chicken Rice (Mentor Eric Teo)
# 1    2  Ah Five Hainanese Chicken Rice / Fried Rice / ...
# 2    3                     Wee Kim Hainanese Chicken Rice
# 3    4                               Henry's Chicken Rice
# 4    5             Hai Nan Xu Ji Chicken Rice (Stall 144)
#
#                                              Address  Postalcode  Latitude  \
# 0  678A Choa Chu Kang Cres, Singapore, Singapore,...      681678  1.401980
# 1        Blk 158 Ang Mo Kio Ave 4, Singapore, 560158      560158  1.374781
# 2                51 Yishun Ave 11, Singapore, 760355      760355  1.424946
# 3             117 Commonwealth Dr, Singapore, 140117      140117  1.306593
# 4        84 Marine Parade Central, Singapore, 440084      440084  1.301962
#
#     Longitude  Operatin_ hour         Type   Google_Rating  No_of_reviews   \
# 0  103.744835   9:30am-8:30pm  Coffee Shop              8.4            303
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   S/N                           100 non-null    int64
#  1   Stall                         100 non-null    object
#  2   Address                       100 non-null    object
#  3   Postalcode                    100 non-null    int64
#  4   Latitude                      100 non-null    float64
#  5   Longitude                     100 non-null    float64
#  6   Operatin_ hour                98 non-null     object
#  7   Type                          100 non-null    object
#  8    Google_Rating                100 non-null    float64
#  9   No_of_reviews                 100 non-null    object
#  10   Cost                         100 non-null    float64
#  11  Chicken_Weight_Grams          100 non-null    float64
# ...

# %%
# df = df.drop(['Remarks','Stall','Address','Operatin_ hour'], axis=1)

# %%
# Make a heatmap for the float and int columns only
import seaborn as sns

# Select only float and int columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Generate the heatmap
sns.heatmap(numeric_df.corr(), cmap='coolwarm')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# Histogram
numeric_df.hist(bins=15, figsize=(15, 10))
plt.suptitle('Histograms of Numeric Columns')
plt.show()

# Box Plot
numeric_df.plot(kind='box', subplots=True, layout=(2, 3), figsize=(15, 10), sharex=False, sharey=False)
plt.suptitle('Box Plots of Numeric Columns')
plt.show()

# Scatter Plot
# Assuming 'col1' and 'col2' are two numeric columns in your DataFrame
plt.figure(figsize=(10, 6))
plt.scatter(numeric_df['col1'], numeric_df['col2'])
plt.title('Scatter Plot between col1 and col2')
plt.xlabel('col1')
plt.ylabel('col2')
plt.show()

# Line Plot
# Assuming 'time' is a time series column and 'value' is a numeric column
plt.figure(figsize=(10, 6))
plt.plot(numeric_df['time'], numeric_df['value'])
plt.title('Line Plot of value over time')
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()

# Pair Plot using seaborn for better visualization
import seaborn as sns
sns.pairplot(numeric_df)
plt.suptitle('Pair Plot of Numeric Columns', y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 9
#       6 plt.show()
#       8 # Box Plot
# ----> 9 numeric_df.plot(kind='box', subplots=True, layout=(2, 3), figsize=(15, 10), sharex=False, sharey=False)
#      10 plt.suptitle('Box Plots of Numeric Columns')
#      11 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
student_data = pd.read_csv('student_data.csv')
student_data.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
import seaborn as sns

# Generate the heatmap
sns.heatmap(student_data.corr(), cmap='coolwarm')
# Out:
# <Axes: >
